# %%
import cv2
import os
import supervision as sv 
from ultralytics import YOLO
import numpy as np 
from enum import Enum

# %%
VIDEO_PATH = r"../../data/raw/videos/cctv/LeaveNGoInBus1.mp4"
MODEL_PATH = r"model/yolov8l.pt"
LEG_DETECTOR_PATH = r"../../results/weights/best.pt"
TOLERANCE = 10
REGION = {
    "5": 671,
    "4": 1761,
}

model = YOLO(MODEL_PATH)
tracker = sv.ByteTrack()
colorAnnotator = sv.ColorAnnotator()

class BusStatus(Enum):
    NO_DETECT = "No bus detected" # wont be used, if dont have bus then centroid will be empty 
    LEAVE_BUS = "Passengers on the bus are getting off"
    WAITING = "Wait for passengers to board" # wait when have ppl up / after ppl down / after resting 
    RESTING = "The bus driver is taking a break"
    DETECTING = "Detecting"
    LEAVING = "The bus is leaving for the next stop"
    
    def __str__(self) :
        return self.value

# %%
# use to store the bus current location id : {centroid, numberMatch, station, status}
busCentroid = {} 
avgLeg = []

# %%
def isBusExist(result) :
    return True if len(result[0].boxes.xyxy) > 0 else False

# clear when the bus is leaving  
def clearBusLocation() : 
    global busCentroid
    busCentroid = {}

def isBusCentroidExist(busId, centroid = busCentroid) : 
    return busId in centroid

# match the tolerance windown
def isWithinRange(currentCentroid, prevCentroid, tolerance = TOLERANCE) : 
    # calculate the euclidean distance between current and previous  
    euclideanDistance = np.linalg.norm(prevCentroid - currentCentroid)
    return euclideanDistance <= tolerance

def updateBusStatus(busId, status) : 
    global busCentroid 
    busCentroid[busId]["status"] = status

def getRegion(centroidX) : 
    for x in REGION :
        if centroidX < REGION[x] : 
            return x
    # outside station 4 and 5 
    return None 

def isLeave(bbox) : 
    # check bus xyxy is outside the x of station 4
    # if outside means already leave 
    # bbox[3] = bottom right corner 
    return bbox[2] >= REGION["4"]

# %%
# check filepath exist 
if not os.path.exists(VIDEO_PATH) : 
    # not exist raise an error 
    raise FileNotFoundError("Video doesnot exist")

# read video 
cap = cv2.VideoCapture(VIDEO_PATH)

while cap.isOpened() : 
    ret, frame = cap.read()

    if not ret : 
        # target resource have problem, unable to continue support execute 
        raise FileNotFoundError("Video doesnot exist")

    # detect bus 
    result = model(frame, classes=[5])[0]

    # check bus exist 
    if isBusExist(result) : 
        # bus exist - check moving 
        detections = sv.Detections.from_ultralytics(result[0])
        tracks = tracker.update_with_detections(detections)
        annotatedFrame = colorAnnotator.annotate(scene=frame.copy(), detections=detections)

        # loop track get centroid
        for track in tracks : 
            # get id and boundary box 
            busId = track[3]
            bbox = track[0]

            # calculate center 
            centerX = (bbox[0] + bbox[2])/2
            centerY = (bbox[1] + bbox[3])/2

            currentLocation = np.array([centerX, centerY])

            if not isBusCentroidExist(busId) : 
                # busid doesnot exist in the dictionary - create one 
                # init 
                busCentroid[busId] = {}
                busCentroid[busId]["centroid"] = currentLocation
                busCentroid[busId]["numberMatch"] = 0
                busCentroid[busId]["station"] = None
                updateBusStatus(busId, BusStatus.DETECTING)
            else :  
                # compare busCentroid, if same for 10 frame means stopping, else store the busCentroid and status = moving 
                # counter 
                prevLocation = busCentroid[busId]["centroid"]
                if isWithinRange(currentCentroid=currentLocation, prevCentroid=prevLocation) : 
                    # within the tolerance window 
                    # update the value 
                    busCentroid[busId]["numberMatch"] += 1

                    if busCentroid[busId]["numberMatch"] >= 10 : 
                        # means stopping 
                        updateBusStatus(busId, BusStatus.WAITING)
                    else : 
                        # not reach 10 
                        updateBusStatus(busId, BusStatus.DETECTING)
                else : 
                    # because not match means is moving so clear the numberMatch 
                    busCentroid[busId]["numberMatch"] = 0 
                    busCentroid[busId]["centroid"] = currentLocation

                    # check is leave or just only moving 
                    if busCentroid[busId]["status"] == BusStatus.WAITING : 
                        # if previous data is waiting means now is leave 
                        updateBusStatus(busId, BusStatus.LEAVING)
                    else : 
                        # just moving 
                        updateBusStatus(busId, BusStatus.DETECTING)

            # do station checking
            # if station have value then move means is ready to leave 
            # only will have 3 case , station = None / station == tempStation / station != tempStation 
            tempStation = getRegion(busCentroid[busId]["centroid"][0])
            if busCentroid[busId]["station"] is None or (busCentroid[busId]["status"] != BusStatus.LEAVING and busCentroid[busId]["status"] != BusStatus.WAITING) : 
                # since waiting and leaving wont affect the station 
                # resting also wont
                busCentroid[busId]["station"] = tempStation

            if isLeave(bbox) : 
                # check the xyxy is outside already or not 
                # if yes then clear the busCentroid
                # remove the bus from centroid and get next bus schedule time 
                busCentroid.pop(busId, None)

            print(f"bus > {busCentroid}")
            frame = annotatedFrame
    else : 
        print("nothings")

    # Draw bounding box
    x_min, y_min, x_max, y_max = map(int, bbox)
    cv2.rectangle(frame, (x_min, y_min), (x_max, y_max), (0, 255, 0), 2)  # Green box

    # Display Bus ID, Status, and Station
    text = (f"ID: {busId}, "
            f"Status: {busCentroid[busId]['status']}, "
            f"Station: {busCentroid[busId]['station']}")
    cv2.putText(frame, text, (x_min, y_min - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)

    # Display Centroid
    centroid_text = f"Centroid: ({int(centerX)}, {int(centerY)})"
    cv2.putText(frame, centroid_text, (x_min, y_max + 20), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 0, 0), 2)
    cv2.circle(frame, (int(centerX), int(centerY)), 5, (0, 0, 255), -1)  # Red dot for centroid

    cv2.imshow("show", frame)
    
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
# Out:
# 0: 384x640 1 bus, 523.2ms
# Speed: 3.5ms preprocess, 523.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     13.699,      497.91], dtype=float32), 'numberMatch': 0, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 509.2ms
# Speed: 4.0ms preprocess, 509.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     13.699,      497.91], dtype=float32), 'numberMatch': 1, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 478.3ms
# Speed: 3.0ms preprocess, 478.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     18.571,      491.76], dtype=float32), 'numberMatch': 0, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 443.2ms
# Speed: 3.0ms preprocess, 443.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([      23.14,       489.5], dtype=float32), 'numberMatch': 0, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 441.7ms
# Speed: 3.0ms preprocess, 441.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([      23.14,       489.5], dtype=float32), 'numberMatch': 1, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 438.4ms
# Speed: 3.1ms preprocess, 438.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     30.043,      483.34], dtype=float32), 'numberMatch': 0, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 442.9ms
# Speed: 2.7ms preprocess, 442.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     35.351,      482.63], dtype=float32), 'numberMatch': 0, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 449.0ms
# Speed: 4.0ms preprocess, 449.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     35.351,      482.63], dtype=float32), 'numberMatch': 1, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 438.4ms
# Speed: 3.9ms preprocess, 438.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     35.351,      482.63], dtype=float32), 'numberMatch': 2, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 438.6ms
# Speed: 2.5ms preprocess, 438.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     41.803,      479.33], dtype=float32), 'numberMatch': 0, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 443.2ms
# Speed: 3.0ms preprocess, 443.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     41.803,      479.33], dtype=float32), 'numberMatch': 1, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 440.4ms
# Speed: 3.5ms preprocess, 440.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 444.3ms
# Speed: 2.0ms preprocess, 444.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     55.872,      478.68], dtype=float32), 'numberMatch': 0, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 552.6ms
# Speed: 3.5ms preprocess, 552.6ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     55.872,      478.68], dtype=float32), 'numberMatch': 1, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 471.6ms
# Speed: 2.9ms preprocess, 471.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     55.872,      478.68], dtype=float32), 'numberMatch': 2, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 459.6ms
# Speed: 2.5ms preprocess, 459.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     61.079,      482.58], dtype=float32), 'numberMatch': 0, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 475.1ms
# Speed: 3.0ms preprocess, 475.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     61.079,      482.58], dtype=float32), 'numberMatch': 1, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 454.2ms
# Speed: 3.5ms preprocess, 454.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     67.766,      483.89], dtype=float32), 'numberMatch': 0, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 453.5ms
# Speed: 2.5ms preprocess, 453.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     72.347,      487.97], dtype=float32), 'numberMatch': 0, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 460.8ms
# Speed: 3.0ms preprocess, 460.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     72.347,      487.97], dtype=float32), 'numberMatch': 1, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 466.4ms
# Speed: 3.3ms preprocess, 466.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     76.937,      490.33], dtype=float32), 'numberMatch': 0, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 463.0ms
# Speed: 3.5ms preprocess, 463.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     76.937,      490.33], dtype=float32), 'numberMatch': 1, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 480.0ms
# Speed: 3.0ms preprocess, 480.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     83.421,      491.91], dtype=float32), 'numberMatch': 0, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 476.2ms
# Speed: 2.0ms preprocess, 476.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     83.421,      491.91], dtype=float32), 'numberMatch': 1, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 451.2ms
# Speed: 4.6ms preprocess, 451.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     91.743,      492.66], dtype=float32), 'numberMatch': 0, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 453.2ms
# Speed: 3.5ms preprocess, 453.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     91.743,      492.66], dtype=float32), 'numberMatch': 1, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 477.5ms
# Speed: 3.5ms preprocess, 477.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     91.743,      492.66], dtype=float32), 'numberMatch': 2, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 486.1ms
# Speed: 3.0ms preprocess, 486.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     98.911,      488.44], dtype=float32), 'numberMatch': 0, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 480.2ms
# Speed: 3.5ms preprocess, 480.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     98.911,      488.44], dtype=float32), 'numberMatch': 1, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 481.8ms
# Speed: 2.0ms preprocess, 481.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     107.76,      481.66], dtype=float32), 'numberMatch': 0, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 492.1ms
# Speed: 3.0ms preprocess, 492.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     107.76,      481.66], dtype=float32), 'numberMatch': 1, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 495.4ms
# Speed: 3.5ms preprocess, 495.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     107.76,      481.66], dtype=float32), 'numberMatch': 2, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 484.6ms
# Speed: 2.1ms preprocess, 484.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     115.13,      476.68], dtype=float32), 'numberMatch': 0, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 485.6ms
# Speed: 3.0ms preprocess, 485.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     115.13,      476.68], dtype=float32), 'numberMatch': 1, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 599.6ms
# Speed: 2.3ms preprocess, 599.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     120.92,      475.14], dtype=float32), 'numberMatch': 0, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 528.4ms
# Speed: 2.1ms preprocess, 528.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     120.92,      475.14], dtype=float32), 'numberMatch': 1, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 492.2ms
# Speed: 4.0ms preprocess, 492.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     120.92,      475.14], dtype=float32), 'numberMatch': 2, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 493.8ms
# Speed: 3.0ms preprocess, 493.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     120.92,      475.14], dtype=float32), 'numberMatch': 3, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 489.3ms
# Speed: 3.6ms preprocess, 489.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     120.92,      475.14], dtype=float32), 'numberMatch': 4, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 451.6ms
# Speed: 2.5ms preprocess, 451.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     120.92,      475.14], dtype=float32), 'numberMatch': 5, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 455.0ms
# Speed: 3.0ms preprocess, 455.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     124.96,      479.39], dtype=float32), 'numberMatch': 0, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 449.8ms
# Speed: 3.5ms preprocess, 449.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     143.29,      478.62], dtype=float32), 'numberMatch': 0, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 450.0ms
# Speed: 3.0ms preprocess, 450.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     151.78,      482.66], dtype=float32), 'numberMatch': 0, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 452.8ms
# Speed: 2.5ms preprocess, 452.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     151.78,      482.66], dtype=float32), 'numberMatch': 1, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 463.2ms
# Speed: 4.6ms preprocess, 463.2ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     151.78,      482.66], dtype=float32), 'numberMatch': 2, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 463.1ms
# Speed: 2.1ms preprocess, 463.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     159.26,       483.7], dtype=float32), 'numberMatch': 0, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 457.2ms
# Speed: 2.5ms preprocess, 457.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     159.26,       483.7], dtype=float32), 'numberMatch': 1, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 459.0ms
# Speed: 2.0ms preprocess, 459.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([      179.4,      485.55], dtype=float32), 'numberMatch': 0, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 455.4ms
# Speed: 3.0ms preprocess, 455.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([      179.4,      485.55], dtype=float32), 'numberMatch': 1, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 454.6ms
# Speed: 3.0ms preprocess, 454.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     174.37,      485.69], dtype=float32), 'numberMatch': 0, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 455.7ms
# Speed: 2.0ms preprocess, 455.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     174.37,      485.69], dtype=float32), 'numberMatch': 1, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 454.6ms
# Speed: 2.0ms preprocess, 454.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     183.38,      488.59], dtype=float32), 'numberMatch': 0, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 454.7ms
# Speed: 2.0ms preprocess, 454.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     183.38,      488.59], dtype=float32), 'numberMatch': 1, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 462.3ms
# Speed: 4.0ms preprocess, 462.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     183.38,      488.59], dtype=float32), 'numberMatch': 2, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 565.1ms
# Speed: 4.0ms preprocess, 565.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     200.81,      488.45], dtype=float32), 'numberMatch': 0, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 723.4ms
# Speed: 4.6ms preprocess, 723.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     200.81,      488.45], dtype=float32), 'numberMatch': 1, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 670.1ms
# Speed: 5.0ms preprocess, 670.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     207.55,      488.96], dtype=float32), 'numberMatch': 0, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 1137.7ms
# Speed: 4.2ms preprocess, 1137.7ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([      202.6,      487.76], dtype=float32), 'numberMatch': 0, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 763.8ms
# Speed: 4.3ms preprocess, 763.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([      202.6,      487.76], dtype=float32), 'numberMatch': 1, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 627.8ms
# Speed: 4.2ms preprocess, 627.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([      202.6,      487.76], dtype=float32), 'numberMatch': 2, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 636.6ms
# Speed: 6.1ms preprocess, 636.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     209.84,      487.61], dtype=float32), 'numberMatch': 0, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 547.1ms
# Speed: 2.1ms preprocess, 547.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     209.84,      487.61], dtype=float32), 'numberMatch': 1, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 530.9ms
# Speed: 3.0ms preprocess, 530.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     209.84,      487.61], dtype=float32), 'numberMatch': 2, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 515.2ms
# Speed: 3.0ms preprocess, 515.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     217.12,      487.83], dtype=float32), 'numberMatch': 0, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 494.7ms
# Speed: 3.6ms preprocess, 494.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     222.51,      488.07], dtype=float32), 'numberMatch': 0, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 486.9ms
# Speed: 3.0ms preprocess, 486.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     222.51,      488.07], dtype=float32), 'numberMatch': 1, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 457.4ms
# Speed: 1.5ms preprocess, 457.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     228.23,      487.85], dtype=float32), 'numberMatch': 0, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 456.8ms
# Speed: 3.0ms preprocess, 456.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     228.23,      487.85], dtype=float32), 'numberMatch': 1, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 457.1ms
# Speed: 4.0ms preprocess, 457.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     228.23,      487.85], dtype=float32), 'numberMatch': 2, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 462.3ms
# Speed: 2.5ms preprocess, 462.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([      236.9,       489.8], dtype=float32), 'numberMatch': 0, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 456.5ms
# Speed: 2.0ms preprocess, 456.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([      236.9,       489.8], dtype=float32), 'numberMatch': 1, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 497.3ms
# Speed: 3.5ms preprocess, 497.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     243.19,      490.62], dtype=float32), 'numberMatch': 0, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 489.2ms
# Speed: 1.8ms preprocess, 489.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     243.19,      490.62], dtype=float32), 'numberMatch': 1, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 513.8ms
# Speed: 3.1ms preprocess, 513.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     251.18,      491.89], dtype=float32), 'numberMatch': 0, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 458.8ms
# Speed: 2.0ms preprocess, 458.8ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     251.18,      491.89], dtype=float32), 'numberMatch': 1, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 456.2ms
# Speed: 2.0ms preprocess, 456.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     256.11,      492.88], dtype=float32), 'numberMatch': 0, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 455.4ms
# Speed: 3.0ms preprocess, 455.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     268.19,      492.62], dtype=float32), 'numberMatch': 0, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 515.5ms
# Speed: 3.4ms preprocess, 515.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     268.19,      492.62], dtype=float32), 'numberMatch': 1, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 452.7ms
# Speed: 3.0ms preprocess, 452.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     268.19,      492.62], dtype=float32), 'numberMatch': 2, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 452.0ms
# Speed: 3.0ms preprocess, 452.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     268.19,      492.62], dtype=float32), 'numberMatch': 3, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 449.6ms
# Speed: 4.0ms preprocess, 449.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     268.19,      492.62], dtype=float32), 'numberMatch': 4, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 455.6ms
# Speed: 2.0ms preprocess, 455.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([      274.3,      492.53], dtype=float32), 'numberMatch': 0, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 448.6ms
# Speed: 2.0ms preprocess, 448.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([      274.3,      492.53], dtype=float32), 'numberMatch': 1, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 455.5ms
# Speed: 2.0ms preprocess, 455.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     281.27,      492.41], dtype=float32), 'numberMatch': 0, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 467.5ms
# Speed: 4.1ms preprocess, 467.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     281.27,      492.41], dtype=float32), 'numberMatch': 1, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 455.8ms
# Speed: 3.0ms preprocess, 455.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     287.54,      497.21], dtype=float32), 'numberMatch': 0, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 487.2ms
# Speed: 3.0ms preprocess, 487.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     287.54,      497.21], dtype=float32), 'numberMatch': 1, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 495.0ms
# Speed: 3.0ms preprocess, 495.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     292.14,      495.01], dtype=float32), 'numberMatch': 0, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 476.8ms
# Speed: 2.0ms preprocess, 476.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     297.16,      495.99], dtype=float32), 'numberMatch': 0, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 488.3ms
# Speed: 4.0ms preprocess, 488.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     303.79,      496.15], dtype=float32), 'numberMatch': 0, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 496.9ms
# Speed: 2.0ms preprocess, 496.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     303.79,      496.15], dtype=float32), 'numberMatch': 1, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 492.5ms
# Speed: 4.0ms preprocess, 492.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     309.21,      495.32], dtype=float32), 'numberMatch': 0, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 488.5ms
# Speed: 4.0ms preprocess, 488.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     309.21,      495.32], dtype=float32), 'numberMatch': 1, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 545.8ms
# Speed: 4.3ms preprocess, 545.8ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     309.21,      495.32], dtype=float32), 'numberMatch': 2, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 586.7ms
# Speed: 3.0ms preprocess, 586.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     316.07,       496.2], dtype=float32), 'numberMatch': 0, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 542.7ms
# Speed: 3.0ms preprocess, 542.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     321.41,      496.24], dtype=float32), 'numberMatch': 0, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 460.7ms
# Speed: 3.5ms preprocess, 460.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     321.41,      496.24], dtype=float32), 'numberMatch': 1, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 451.6ms
# Speed: 4.0ms preprocess, 451.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     327.86,      495.42], dtype=float32), 'numberMatch': 0, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 454.8ms
# Speed: 2.0ms preprocess, 454.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     327.86,      495.42], dtype=float32), 'numberMatch': 1, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 465.5ms
# Speed: 1.8ms preprocess, 465.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     332.17,      498.06], dtype=float32), 'numberMatch': 0, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 477.7ms
# Speed: 3.0ms preprocess, 477.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     339.99,      498.48], dtype=float32), 'numberMatch': 0, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 453.5ms
# Speed: 3.0ms preprocess, 453.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     339.99,      498.48], dtype=float32), 'numberMatch': 1, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 454.5ms
# Speed: 3.0ms preprocess, 454.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     350.75,         497], dtype=float32), 'numberMatch': 0, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 470.7ms
# Speed: 3.0ms preprocess, 470.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     357.45,      499.11], dtype=float32), 'numberMatch': 0, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 497.9ms
# Speed: 4.0ms preprocess, 497.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     357.45,      499.11], dtype=float32), 'numberMatch': 1, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 553.8ms
# Speed: 4.0ms preprocess, 553.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     357.45,      499.11], dtype=float32), 'numberMatch': 2, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 457.6ms
# Speed: 4.0ms preprocess, 457.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     365.33,      499.88], dtype=float32), 'numberMatch': 0, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 452.3ms
# Speed: 3.0ms preprocess, 452.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     371.75,      502.51], dtype=float32), 'numberMatch': 0, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 454.6ms
# Speed: 3.0ms preprocess, 454.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     376.61,      504.58], dtype=float32), 'numberMatch': 0, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 452.7ms
# Speed: 3.0ms preprocess, 452.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     376.61,      504.58], dtype=float32), 'numberMatch': 1, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 457.7ms
# Speed: 4.0ms preprocess, 457.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     376.61,      504.58], dtype=float32), 'numberMatch': 2, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 456.1ms
# Speed: 3.0ms preprocess, 456.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     372.36,      509.23], dtype=float32), 'numberMatch': 0, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 478.3ms
# Speed: 3.0ms preprocess, 478.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     372.36,      509.23], dtype=float32), 'numberMatch': 1, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 458.8ms
# Speed: 4.0ms preprocess, 458.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     380.81,      511.27], dtype=float32), 'numberMatch': 0, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 457.3ms
# Speed: 2.0ms preprocess, 457.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     394.11,      511.06], dtype=float32), 'numberMatch': 0, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 455.4ms
# Speed: 4.0ms preprocess, 455.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     394.11,      511.06], dtype=float32), 'numberMatch': 1, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 480.6ms
# Speed: 3.0ms preprocess, 480.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     394.11,      511.06], dtype=float32), 'numberMatch': 2, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 500.5ms
# Speed: 4.0ms preprocess, 500.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     394.11,      511.06], dtype=float32), 'numberMatch': 3, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 544.8ms
# Speed: 3.0ms preprocess, 544.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     394.11,      511.06], dtype=float32), 'numberMatch': 4, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 494.2ms
# Speed: 3.0ms preprocess, 494.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     394.11,      511.06], dtype=float32), 'numberMatch': 5, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 490.1ms
# Speed: 3.0ms preprocess, 490.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     401.21,      511.61], dtype=float32), 'numberMatch': 0, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 494.7ms
# Speed: 3.0ms preprocess, 494.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     401.21,      511.61], dtype=float32), 'numberMatch': 1, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 497.2ms
# Speed: 3.0ms preprocess, 497.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     401.21,      511.61], dtype=float32), 'numberMatch': 2, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 499.9ms
# Speed: 3.0ms preprocess, 499.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     409.77,      512.86], dtype=float32), 'numberMatch': 0, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 488.7ms
# Speed: 5.8ms preprocess, 488.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     409.77,      512.86], dtype=float32), 'numberMatch': 1, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 487.8ms
# Speed: 3.0ms preprocess, 487.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     416.72,      514.07], dtype=float32), 'numberMatch': 0, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 529.0ms
# Speed: 3.0ms preprocess, 529.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     416.72,      514.07], dtype=float32), 'numberMatch': 1, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 454.2ms
# Speed: 4.0ms preprocess, 454.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     423.72,      514.68], dtype=float32), 'numberMatch': 0, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 455.9ms
# Speed: 2.0ms preprocess, 455.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     423.72,      514.68], dtype=float32), 'numberMatch': 1, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 454.0ms
# Speed: 2.0ms preprocess, 454.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     423.72,      514.68], dtype=float32), 'numberMatch': 2, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 449.1ms
# Speed: 3.8ms preprocess, 449.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     431.79,      515.73], dtype=float32), 'numberMatch': 0, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 452.1ms
# Speed: 3.8ms preprocess, 452.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     431.79,      515.73], dtype=float32), 'numberMatch': 1, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 512.8ms
# Speed: 3.0ms preprocess, 512.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     439.03,      515.95], dtype=float32), 'numberMatch': 0, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 456.1ms
# Speed: 3.0ms preprocess, 456.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     439.03,      515.95], dtype=float32), 'numberMatch': 1, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 454.9ms
# Speed: 3.0ms preprocess, 454.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     439.03,      515.95], dtype=float32), 'numberMatch': 2, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 456.9ms
# Speed: 3.0ms preprocess, 456.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     448.39,       517.5], dtype=float32), 'numberMatch': 0, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 472.1ms
# Speed: 2.0ms preprocess, 472.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     455.02,      515.53], dtype=float32), 'numberMatch': 0, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 470.5ms
# Speed: 3.0ms preprocess, 470.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     461.22,      516.41], dtype=float32), 'numberMatch': 0, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 455.1ms
# Speed: 3.0ms preprocess, 455.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     468.13,      517.29], dtype=float32), 'numberMatch': 0, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 452.4ms
# Speed: 3.0ms preprocess, 452.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     477.39,      519.16], dtype=float32), 'numberMatch': 0, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 456.0ms
# Speed: 3.3ms preprocess, 456.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     477.39,      519.16], dtype=float32), 'numberMatch': 1, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 452.9ms
# Speed: 2.0ms preprocess, 452.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     484.28,      519.02], dtype=float32), 'numberMatch': 0, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 451.8ms
# Speed: 4.0ms preprocess, 451.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     484.28,      519.02], dtype=float32), 'numberMatch': 1, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 454.0ms
# Speed: 2.0ms preprocess, 454.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([      496.5,      520.83], dtype=float32), 'numberMatch': 0, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 453.4ms
# Speed: 3.0ms preprocess, 453.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     504.18,      520.92], dtype=float32), 'numberMatch': 0, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 484.7ms
# Speed: 3.0ms preprocess, 484.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     510.97,      523.17], dtype=float32), 'numberMatch': 0, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 487.0ms
# Speed: 3.0ms preprocess, 487.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     510.97,      523.17], dtype=float32), 'numberMatch': 1, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 494.6ms
# Speed: 3.0ms preprocess, 494.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     517.68,      525.37], dtype=float32), 'numberMatch': 0, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 556.3ms
# Speed: 4.0ms preprocess, 556.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     524.35,      523.81], dtype=float32), 'numberMatch': 0, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 524.4ms
# Speed: 4.0ms preprocess, 524.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     531.24,      522.89], dtype=float32), 'numberMatch': 0, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 496.4ms
# Speed: 2.0ms preprocess, 496.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     536.25,      525.06], dtype=float32), 'numberMatch': 0, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 493.7ms
# Speed: 2.0ms preprocess, 493.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     541.91,      524.73], dtype=float32), 'numberMatch': 0, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 506.7ms
# Speed: 3.0ms preprocess, 506.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     541.91,      524.73], dtype=float32), 'numberMatch': 1, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 504.8ms
# Speed: 4.0ms preprocess, 504.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     546.83,      525.65], dtype=float32), 'numberMatch': 0, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 494.1ms
# Speed: 3.0ms preprocess, 494.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     546.83,      525.65], dtype=float32), 'numberMatch': 1, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 493.4ms
# Speed: 3.8ms preprocess, 493.4ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     558.83,      527.24], dtype=float32), 'numberMatch': 0, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 491.5ms
# Speed: 2.2ms preprocess, 491.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     564.62,      529.29], dtype=float32), 'numberMatch': 0, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 504.0ms
# Speed: 4.0ms preprocess, 504.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     571.34,      528.28], dtype=float32), 'numberMatch': 0, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 510.2ms
# Speed: 2.0ms preprocess, 510.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     571.34,      528.28], dtype=float32), 'numberMatch': 1, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 457.5ms
# Speed: 3.0ms preprocess, 457.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([      576.7,      528.45], dtype=float32), 'numberMatch': 0, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 453.2ms
# Speed: 2.0ms preprocess, 453.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     581.44,      530.45], dtype=float32), 'numberMatch': 0, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 453.2ms
# Speed: 3.0ms preprocess, 453.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     581.44,      530.45], dtype=float32), 'numberMatch': 1, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 450.3ms
# Speed: 3.0ms preprocess, 450.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     587.65,      529.75], dtype=float32), 'numberMatch': 0, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 449.5ms
# Speed: 4.0ms preprocess, 449.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     587.65,      529.75], dtype=float32), 'numberMatch': 1, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 457.6ms
# Speed: 2.0ms preprocess, 457.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     587.65,      529.75], dtype=float32), 'numberMatch': 2, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 510.7ms
# Speed: 4.1ms preprocess, 510.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     592.99,      533.05], dtype=float32), 'numberMatch': 0, 'station': '5', 'status': <BusStatus.DETECTING: 'Detecting'>}}
#
# 0: 384x640 1 bus, 466.4ms
# Speed: 3.0ms preprocess, 466.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# ...
#
# 0: 384x640 1 bus, 460.9ms
# Speed: 2.0ms preprocess, 460.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     949.43,      545.62], dtype=float32), 'numberMatch': 14, 'station': '4', 'status': <BusStatus.WAITING: 'Wait for passengers to board'>}}
#
# 0: 384x640 1 bus, 457.1ms
# Speed: 3.0ms preprocess, 457.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     949.43,      545.62], dtype=float32), 'numberMatch': 15, 'station': '4', 'status': <BusStatus.WAITING: 'Wait for passengers to board'>}}
#
# 0: 384x640 1 bus, 467.3ms
# Speed: 2.0ms preprocess, 467.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     949.43,      545.62], dtype=float32), 'numberMatch': 16, 'station': '4', 'status': <BusStatus.WAITING: 'Wait for passengers to board'>}}
#
# 0: 384x640 1 bus, 455.1ms
# Speed: 4.0ms preprocess, 455.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     949.43,      545.62], dtype=float32), 'numberMatch': 17, 'station': '4', 'status': <BusStatus.WAITING: 'Wait for passengers to board'>}}
#
# 0: 384x640 1 bus, 458.1ms
# Speed: 4.1ms preprocess, 458.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     949.43,      545.62], dtype=float32), 'numberMatch': 18, 'station': '4', 'status': <BusStatus.WAITING: 'Wait for passengers to board'>}}
#
# 0: 384x640 1 bus, 485.5ms
# Speed: 4.0ms preprocess, 485.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     949.43,      545.62], dtype=float32), 'numberMatch': 19, 'station': '4', 'status': <BusStatus.WAITING: 'Wait for passengers to board'>}}
#
# 0: 384x640 1 bus, 522.0ms
# Speed: 3.0ms preprocess, 522.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     949.43,      545.62], dtype=float32), 'numberMatch': 20, 'station': '4', 'status': <BusStatus.WAITING: 'Wait for passengers to board'>}}
#
# 0: 384x640 1 bus, 466.3ms
# Speed: 3.3ms preprocess, 466.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     949.43,      545.62], dtype=float32), 'numberMatch': 21, 'station': '4', 'status': <BusStatus.WAITING: 'Wait for passengers to board'>}}
#
# 0: 384x640 1 bus, 457.0ms
# Speed: 3.0ms preprocess, 457.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     949.43,      545.62], dtype=float32), 'numberMatch': 22, 'station': '4', 'status': <BusStatus.WAITING: 'Wait for passengers to board'>}}
#
# 0: 384x640 1 bus, 458.7ms
# Speed: 3.0ms preprocess, 458.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     949.43,      545.62], dtype=float32), 'numberMatch': 23, 'station': '4', 'status': <BusStatus.WAITING: 'Wait for passengers to board'>}}
#
# 0: 384x640 1 bus, 459.7ms
# Speed: 3.0ms preprocess, 459.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     949.43,      545.62], dtype=float32), 'numberMatch': 24, 'station': '4', 'status': <BusStatus.WAITING: 'Wait for passengers to board'>}}
#
# 0: 384x640 1 bus, 455.0ms
# Speed: 3.0ms preprocess, 455.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     949.43,      545.62], dtype=float32), 'numberMatch': 25, 'station': '4', 'status': <BusStatus.WAITING: 'Wait for passengers to board'>}}
#
# 0: 384x640 1 bus, 456.9ms
# Speed: 3.4ms preprocess, 456.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     949.43,      545.62], dtype=float32), 'numberMatch': 26, 'station': '4', 'status': <BusStatus.WAITING: 'Wait for passengers to board'>}}
#
# 0: 384x640 1 bus, 457.7ms
# Speed: 2.0ms preprocess, 457.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     949.43,      545.62], dtype=float32), 'numberMatch': 27, 'station': '4', 'status': <BusStatus.WAITING: 'Wait for passengers to board'>}}
#
# 0: 384x640 1 bus, 459.9ms
# Speed: 3.0ms preprocess, 459.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     949.43,      545.62], dtype=float32), 'numberMatch': 28, 'station': '4', 'status': <BusStatus.WAITING: 'Wait for passengers to board'>}}
#
# 0: 384x640 1 bus, 459.4ms
# Speed: 3.0ms preprocess, 459.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     949.43,      545.62], dtype=float32), 'numberMatch': 29, 'station': '4', 'status': <BusStatus.WAITING: 'Wait for passengers to board'>}}
#
# 0: 384x640 1 bus, 623.9ms
# Speed: 3.0ms preprocess, 623.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     949.43,      545.62], dtype=float32), 'numberMatch': 30, 'station': '4', 'status': <BusStatus.WAITING: 'Wait for passengers to board'>}}
#
# 0: 384x640 1 bus, 522.1ms
# Speed: 3.0ms preprocess, 522.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     949.43,      545.62], dtype=float32), 'numberMatch': 31, 'station': '4', 'status': <BusStatus.WAITING: 'Wait for passengers to board'>}}
#
# 0: 384x640 1 bus, 512.8ms
# Speed: 3.0ms preprocess, 512.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     949.43,      545.62], dtype=float32), 'numberMatch': 32, 'station': '4', 'status': <BusStatus.WAITING: 'Wait for passengers to board'>}}
#
# 0: 384x640 1 bus, 512.9ms
# Speed: 4.0ms preprocess, 512.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     949.43,      545.62], dtype=float32), 'numberMatch': 33, 'station': '4', 'status': <BusStatus.WAITING: 'Wait for passengers to board'>}}
#
# 0: 384x640 1 bus, 516.0ms
# Speed: 3.0ms preprocess, 516.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     949.43,      545.62], dtype=float32), 'numberMatch': 34, 'station': '4', 'status': <BusStatus.WAITING: 'Wait for passengers to board'>}}
#
# 0: 384x640 1 bus, 519.7ms
# Speed: 3.8ms preprocess, 519.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     949.43,      545.62], dtype=float32), 'numberMatch': 35, 'station': '4', 'status': <BusStatus.WAITING: 'Wait for passengers to board'>}}
#
# 0: 384x640 1 bus, 514.4ms
# Speed: 2.0ms preprocess, 514.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     949.43,      545.62], dtype=float32), 'numberMatch': 36, 'station': '4', 'status': <BusStatus.WAITING: 'Wait for passengers to board'>}}
#
# 0: 384x640 1 bus, 522.2ms
# Speed: 2.0ms preprocess, 522.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     949.43,      545.62], dtype=float32), 'numberMatch': 37, 'station': '4', 'status': <BusStatus.WAITING: 'Wait for passengers to board'>}}
#
# 0: 384x640 1 bus, 504.4ms
# Speed: 3.8ms preprocess, 504.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     949.43,      545.62], dtype=float32), 'numberMatch': 38, 'station': '4', 'status': <BusStatus.WAITING: 'Wait for passengers to board'>}}
#
# 0: 384x640 1 bus, 543.4ms
# Speed: 4.0ms preprocess, 543.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     949.43,      545.62], dtype=float32), 'numberMatch': 39, 'station': '4', 'status': <BusStatus.WAITING: 'Wait for passengers to board'>}}
#
# 0: 384x640 1 bus, 480.5ms
# Speed: 5.1ms preprocess, 480.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     949.43,      545.62], dtype=float32), 'numberMatch': 40, 'station': '4', 'status': <BusStatus.WAITING: 'Wait for passengers to board'>}}
#
# 0: 384x640 1 bus, 461.7ms
# Speed: 2.0ms preprocess, 461.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     949.43,      545.62], dtype=float32), 'numberMatch': 41, 'station': '4', 'status': <BusStatus.WAITING: 'Wait for passengers to board'>}}
#
# 0: 384x640 1 bus, 464.7ms
# Speed: 3.5ms preprocess, 464.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     949.43,      545.62], dtype=float32), 'numberMatch': 42, 'station': '4', 'status': <BusStatus.WAITING: 'Wait for passengers to board'>}}
#
# 0: 384x640 1 bus, 455.8ms
# Speed: 3.0ms preprocess, 455.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     949.43,      545.62], dtype=float32), 'numberMatch': 43, 'station': '4', 'status': <BusStatus.WAITING: 'Wait for passengers to board'>}}
#
# 0: 384x640 1 bus, 461.0ms
# Speed: 3.0ms preprocess, 461.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     949.43,      545.62], dtype=float32), 'numberMatch': 44, 'station': '4', 'status': <BusStatus.WAITING: 'Wait for passengers to board'>}}
#
# 0: 384x640 1 bus, 462.2ms
# Speed: 3.0ms preprocess, 462.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     949.43,      545.62], dtype=float32), 'numberMatch': 45, 'station': '4', 'status': <BusStatus.WAITING: 'Wait for passengers to board'>}}
#
# 0: 384x640 1 bus, 457.9ms
# Speed: 3.0ms preprocess, 457.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     949.43,      545.62], dtype=float32), 'numberMatch': 46, 'station': '4', 'status': <BusStatus.WAITING: 'Wait for passengers to board'>}}
#
# 0: 384x640 1 bus, 460.4ms
# Speed: 4.0ms preprocess, 460.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     949.43,      545.62], dtype=float32), 'numberMatch': 47, 'station': '4', 'status': <BusStatus.WAITING: 'Wait for passengers to board'>}}
#
# 0: 384x640 1 bus, 530.3ms
# Speed: 3.0ms preprocess, 530.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     949.43,      545.62], dtype=float32), 'numberMatch': 48, 'station': '4', 'status': <BusStatus.WAITING: 'Wait for passengers to board'>}}
#
# 0: 384x640 1 bus, 482.7ms
# Speed: 1.8ms preprocess, 482.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     949.43,      545.62], dtype=float32), 'numberMatch': 49, 'station': '4', 'status': <BusStatus.WAITING: 'Wait for passengers to board'>}}
#
# 0: 384x640 1 bus, 496.6ms
# Speed: 1.8ms preprocess, 496.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     949.43,      545.62], dtype=float32), 'numberMatch': 50, 'station': '4', 'status': <BusStatus.WAITING: 'Wait for passengers to board'>}}
#
# 0: 384x640 1 bus, 495.5ms
# Speed: 4.0ms preprocess, 495.5ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     949.43,      545.62], dtype=float32), 'numberMatch': 51, 'station': '4', 'status': <BusStatus.WAITING: 'Wait for passengers to board'>}}
#
# 0: 384x640 1 bus, 474.1ms
# Speed: 4.1ms preprocess, 474.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     949.43,      545.62], dtype=float32), 'numberMatch': 52, 'station': '4', 'status': <BusStatus.WAITING: 'Wait for passengers to board'>}}
#
# 0: 384x640 1 bus, 467.6ms
# Speed: 2.0ms preprocess, 467.6ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     949.43,      545.62], dtype=float32), 'numberMatch': 53, 'station': '4', 'status': <BusStatus.WAITING: 'Wait for passengers to board'>}}
#
# 0: 384x640 1 bus, 461.6ms
# Speed: 2.0ms preprocess, 461.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     949.43,      545.62], dtype=float32), 'numberMatch': 54, 'station': '4', 'status': <BusStatus.WAITING: 'Wait for passengers to board'>}}
#
# 0: 384x640 1 bus, 464.2ms
# Speed: 3.5ms preprocess, 464.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     949.43,      545.62], dtype=float32), 'numberMatch': 55, 'station': '4', 'status': <BusStatus.WAITING: 'Wait for passengers to board'>}}
#
# 0: 384x640 1 bus, 571.7ms
# Speed: 4.0ms preprocess, 571.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     949.43,      545.62], dtype=float32), 'numberMatch': 56, 'station': '4', 'status': <BusStatus.WAITING: 'Wait for passengers to board'>}}
#
# 0: 384x640 1 bus, 502.2ms
# Speed: 3.7ms preprocess, 502.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     949.43,      545.62], dtype=float32), 'numberMatch': 57, 'station': '4', 'status': <BusStatus.WAITING: 'Wait for passengers to board'>}}
#
# 0: 384x640 1 bus, 459.0ms
# Speed: 2.0ms preprocess, 459.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     949.43,      545.62], dtype=float32), 'numberMatch': 58, 'station': '4', 'status': <BusStatus.WAITING: 'Wait for passengers to board'>}}
#
# 0: 384x640 1 bus, 473.8ms
# Speed: 2.0ms preprocess, 473.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     949.43,      545.62], dtype=float32), 'numberMatch': 59, 'station': '4', 'status': <BusStatus.WAITING: 'Wait for passengers to board'>}}
#
# 0: 384x640 1 bus, 547.1ms
# Speed: 2.0ms preprocess, 547.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     949.43,      545.62], dtype=float32), 'numberMatch': 60, 'station': '4', 'status': <BusStatus.WAITING: 'Wait for passengers to board'>}}
#
# 0: 384x640 1 bus, 522.3ms
# Speed: 4.0ms preprocess, 522.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     949.43,      545.62], dtype=float32), 'numberMatch': 61, 'station': '4', 'status': <BusStatus.WAITING: 'Wait for passengers to board'>}}
#
# 0: 384x640 1 bus, 520.7ms
# Speed: 3.1ms preprocess, 520.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     949.43,      545.62], dtype=float32), 'numberMatch': 62, 'station': '4', 'status': <BusStatus.WAITING: 'Wait for passengers to board'>}}
#
# 0: 384x640 1 bus, 513.6ms
# Speed: 3.0ms preprocess, 513.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     949.43,      545.62], dtype=float32), 'numberMatch': 63, 'station': '4', 'status': <BusStatus.WAITING: 'Wait for passengers to board'>}}
#
# 0: 384x640 1 bus, 563.6ms
# Speed: 3.0ms preprocess, 563.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     949.43,      545.62], dtype=float32), 'numberMatch': 64, 'station': '4', 'status': <BusStatus.WAITING: 'Wait for passengers to board'>}}
#
# 0: 384x640 1 bus, 554.0ms
# Speed: 2.5ms preprocess, 554.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# bus > {np.int64(5): {'centroid': array([     949.43,      545.62], dtype=float32), 'numberMatch': 65, 'station': '4', 'status': <BusStatus.WAITING: 'Wait for passengers to board'>}}
