# %% [markdown]
# # method 1 - crop certain area +1 -1

# %%
import cv2
import matplotlib.pyplot as plt
from ultralytics import YOLO

# %%
image = cv2.imread("../Source/busStopImage/BS_frame185.jpg")

# %%
x, y, w, h = 0, 350, 74, 288

cropImage = image[y:y+h, x:x+w]

# cv2.imshow("crop", cropImage)
# cv2.waitKey(0)
# cv2.destroyAllWindows()

plt.imshow(cv2.cvtColor(cropImage, cv2.COLOR_BGR2RGB)) 
plt.axis('off')
plt.show()

# %%
# try model able to differentiate or not 
y8 = YOLO("yolov8n.pt")

result = model(cropImage)
# Out:
# 0: 640x192 1 person, 215.5ms
# Speed: 13.1ms preprocess, 215.5ms inference, 13.5ms postprocess per image at shape (1, 3, 640, 192)

# %%
# try to catch this person and give id - track the move 
# bytetrack suitable for real time
